# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from pprint import pprint
import urllib
from random import uniform

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
pprint(cities)
# Out:
# 587
# ['ushuaia',
#  'tuktoyaktuk',
#  'kirakira',
#  'caceres',
#  'hithadhoo',
#  'north bend',
#  'luganville',
#  'nome',
#  'bluff',
#  'aklavik',
#  'atuona',
#  'norman wells',
#  'khatanga',
#  'cidreira',
#  'mataura',
#  'faanui',
#  'kapaa',
#  'miri',
#  'port-cartier',
#  'geraldton',
#  'severo-kurilsk',
#  'katsuura',
#  'lac du bonnet',
#  'nizwa',
#  'eskasem',
#  'albany',
#  'hutchinson',
#  'hare bay',
#  'norrtalje',
#  'samana',
#  'ilulissat',
#  'torbay',
#  'burica',
#  'anadyr',
#  'itoman',
#  'arman',
#  'luena',
#  'port alfred',
#  'cape town',
#  'kushmurun',
#  'husavik',
#  'busselton',
#  'hilo',
#  'castro',
#  'saskylakh',
#  'luderitz',
#  'rognan',
#  'codrington',
#  'tahoua',
#  'sabang',
#  'bamako',
#  'upernavik',
#  'arraial do cabo',
#  'sitka',
#  'ahuimanu',
#  'longyearbyen',
#  'nizhneyansk',
#  'olafsvik',
#  'mar del plata',
#  'amderma',
#  'puerto baquerizo moreno',
#  'lolua',
#  'lisakovsk',
#  'fuente de oro',
#  'tasbuget',
#  'dikson',
#  'russell',
#  'mokrous',
#  'qaanaaq',
#  'jumla',
#  'nikolskoye',
#  'mahebourg',
#  'jamestown',
#  'pevek',
#  'chokurdakh',
#  'saint-philippe',
#  'kem',
#  'punta arenas',
#  'caravelas',
#  'hovd',
#  'hasaki',
#  'rikitea',
#  'taolanaro',
#  'eyl',
#  'bontang',
#  'ostrovnoy',
#  'vanavara',
#  'kanniyakumari',
#  'novaya zaimka',
#  'hamilton',
#  'hermanus',
#  'dekoa',
#  'portland',
#  'samalaeulu',
#  'tiksi',
#  'sadon',
#  'east london',
#  'belushya guba',
#  'pisco',
#  'khonuu',
#  'vaini',
#  'qasigiannguit',
#  'leningradskiy',
#  'chimbote',
#  'barentsburg',
#  'kodiak',
#  'stromness',
#  'port elizabeth',
#  'san patricio',
#  'guilin',
#  'godo',
#  'smithers',
#  'mugango',
#  'lorengau',
#  'yellowknife',
#  'elat',
#  'grand river south east',
#  'avarua',
#  'harper',
#  'calafell',
#  'katav-ivanovsk',
#  'te anau',
#  'malmo',
#  'maniitsoq',
#  'sao joao da barra',
#  'hobart',
#  'samusu',
#  'palmer',
#  'zhangjiakou',
#  'peleduy',
#  'kavieng',
#  'ulundi',
#  'taoudenni',
#  'trinidad',
#  'acajutla',
#  'butaritari',
#  'beringovskiy',
#  'esperance',
#  'hobyo',
#  'xining',
#  'thompson',
#  'namibe',
#  'sisimiut',
#  'barrow',
#  'flinders',
#  'new norfolk',
#  'adrar',
#  'coihaique',
#  'sao lourenco do sul',
#  'airai',
#  'batemans bay',
#  'umzimvubu',
#  'abu kamal',
#  'karaul',
#  'grand gaube',
#  'pafos',
#  'souillac',
#  'sola',
#  'saldanha',
#  'bilma',
#  'salalah',
#  'lieksa',
#  'bethel',
#  'darnah',
#  'pochutla',
#  'elk point',
#  'nanortalik',
#  'piranshahr',
#  'ha tinh',
#  'saleaula',
#  'bell ville',
#  'yarmouth',
#  'illoqqortoormiut',
#  'berlevag',
#  'lebu',
#  'horqueta',
#  'puerto ayora',
#  'constitucion',
#  'tura',
#  'marcona',
#  'along',
#  'kruisfontein',
#  'ugoofaaru',
#  'the valley',
#  'huarmey',
#  'perth',
#  'carnarvon',
#  'tuatapere',
#  'tutoia',
#  'ariquemes',
#  'bengkulu',
#  'benghazi',
#  'victoria',
#  'yatou',
#  'san quintin',
#  'qaqortoq',
#  'kedrovoye',
#  'lasa',
#  'marshall',
#  'cherskiy',
#  'san cristobal',
#  'narsaq',
#  'fortuna',
#  'satitoa',
#  'la ronge',
#  'port hardy',
#  'katangli',
#  'akoupe',
#  'manadhoo',
#  'sao filipe',
#  'volot',
#  'am timan',
#  'cockburn town',
#  'sedona',
#  'kahului',
#  'stokmarknes',
#  'alghero',
#  'zvishavane',
#  'shimoda',
#  'iqaluit',
#  'shingu',
#  'abu samrah',
#  'basco',
#  'tasiilaq',
#  'leh',
#  'waipawa',
#  'inhambane',
#  'ribeira grande',
#  'byron bay',
#  'sechura',
#  'klaksvik',
#  'dvubratskiy',
#  'mapiripan',
#  'puerto colombia',
#  'bathsheba',
#  'umm lajj',
#  'tumannyy',
#  'vaitupu',
#  'ojinaga',
#  'raga',
#  'scottsbluff',
#  'grootfontein',
#  'najran',
#  'mascote',
#  'provideniya',
#  'le port',
#  'skelleftea',
#  'saint-francois',
#  'whitehorse',
#  'raxaul',
#  'khani',
#  'cabo san lucas',
#  'kaitangata',
#  'attawapiskat',
#  'kimberley',
#  'lagoa',
#  'la asuncion',
#  'san policarpo',
#  'kupang',
#  'singapore',
#  'grand baie',
#  'fukue',
#  'bosaso',
#  'tilichiki',
#  'douentza',
#  'bredasdorp',
#  'ponta do sol',
#  'tsiroanomandidy',
#  'vardo',
#  'vitimskiy',
#  'okhotsk',
#  'japura',
#  'tsihombe',
#  'gold coast',
#  'casper',
#  'makasar',
#  'champerico',
#  'zabol',
#  'touros',
#  'richards bay',
#  'sulphur',
#  'talant',
#  'presidente venceslau',
#  'libreville',
#  'ipil',
#  'san clemente',
#  'hofn',
#  'bandarbeyla',
#  'louisbourg',
#  'ballina',
#  'pangnirtung',
#  'henties bay',
#  'shitanjing',
#  'saryshagan',
#  'zhanakorgan',
#  'namatanai',
#  'ouargaye',
#  'antofagasta',
#  'tandalti',
#  'sentyabrskiy',
#  'tecolutla',
#  'amapa',
#  'kaeo',
#  'teguldet',
#  'hirara',
#  'voyvozh',
#  'moose factory',
#  'honningsvag',
#  'sal rei',
#  'port shepstone',
#  'panama city',
#  'marihatag',
#  'turayf',
#  'nioro',
#  'vikulovo',
#  'lancut',
#  'leshukonskoye',
#  'yumen',
#  'mys shmidta',
#  'tucupita',
#  'bogashevo',
#  'camacha',
#  'derzhavinsk',
#  'subang',
#  'praya',
#  'georgetown',
#  'falealupo',
#  'necochea',
#  'kavaratti',
#  'kyshtovka',
#  'zyryanskoye',
#  'pasuruan',
#  'sikea',
#  'mersing',
#  'jutai',
#  'tottori',
#  'iisalmi',
#  'sistranda',
#  'ye',
#  'sandy bay',
#  'roma',
#  'ambon',
#  'ordzhonikidze',
#  'constantine',
#  'ondorhaan',
#  'las vegas',
#  'aswan',
#  'marsaxlokk',
#  'kenai',
#  'isangel',
#  'saint george',
#  'port augusta',
#  'half moon bay',
#  'manzanillo',
#  'kununurra',
#  'kostomuksha',
#  'sterling',
#  'carbonia',
#  'takoradi',
#  'muisne',
#  'yulara',
#  'nago',
#  'fraser',
#  'saint-pierre',
#  'comodoro rivadavia',
#  'kysyl-syr',
#  'manali',
#  'axim',
#  'shelburne',
#  'coquimbo',
#  'kashi',
#  'mega',
#  'guerrero negro',
#  'clyde river',
#  'zhangye',
#  'xanlar',
#  'labuhan',
#  'roald',
#  'lavrentiya',
#  'karratha',
#  'nevinnomyssk',
#  'margate',
#  'tezu',
#  'dukat',
#  'pacific grove',
#  'svetlaya',
#  'cairns',
#  'avare',
#  'ornskoldsvik',
#  'simao',
#  'tlaxiaco',
#  'lata',
#  'moree',
#  'cap-chat',
#  'kachug',
#  'aflu',
#  'sarangani',
#  'colesberg',
#  'mongu',
#  'kloulklubed',
#  'novikovo',
#  'goderich',
#  'filadelfia',
#  'dickinson',
#  'santa cruz de tenerife',
#  'naze',
#  'pedernales',
#  'bubaque',
#  'elko',
#  'rawson',
#  'sibu',
#  'ribeirao branco',
#  'clayton',
#  'barra do garcas',
#  'nuuk',
#  'marfino',
#  'concepcion del oro',
#  'north platte',
#  'khash',
#  'salinopolis',
#  'shevchenkove',
#  'mikun',
#  'harrison',
#  'seoul',
#  'bonavista',
#  'los llanos de aridane',
#  'west wendover',
#  'mayo',
#  'obo',
#  'oranjemund',
#  'makakilo city',
#  'mantua',
#  'meulaboh',
#  'kilindoni',
#  'strai',
#  'isabela',
#  'canon city',
#  'artyk',
#  'voh',
#  'sayyan',
#  'dawei',
#  'dhidhdhoo',
#  'ternate',
#  'paris',
#  'brownsburg',
#  'mount gambier',
#  'taksimo',
#  'manggar',
#  'shenjiamen',
#  'vrangel',
#  'svetlyy',
#  'chuy',
#  'ayan',
#  'andenes',
#  'bingen',
#  'coaldale',
#  'alofi',
#  'chifeng',
#  'bambous virieux',
#  'jujuy',
#  'kalmunai',
#  'bara',
#  'ust-nera',
#  'nouakchott',
#  'havelock',
#  'naila',
#  'cabedelo',
#  'oistins',
#  'carroll',
#  'porto novo',
#  'vila velha',
#  'ancud',
#  'port hedland',
#  'port macquarie',
#  'toftir',
#  'saint-esteve',
#  'cayenne',
#  'tual',
#  'sao felix do xingu',
#  'pitea',
#  'turukhansk',
#  'grenfell',
#  'noumea',
#  'bratsk',
#  'tirana',
#  'auki',
#  'galiwinku',
#  'tocopilla',
#  'maykain',
#  'nevelsk',
#  'pemangkat',
#  'wenatchee',
#  'chornoliztsi',
#  'mwingi',
#  'langarud',
#  'cascais',
#  'marsh harbour',
#  'quatre cocos',
#  'tiznit',
#  'aasiaat',
#  'hambantota',
#  'puerto carreno',
#  'severo-yeniseyskiy',
#  'nykoping',
#  'nantucket',
#  'talnakh',
#  'kurchum',
#  'tidore',
#  'stepnogorsk',
#  'bagn',
#  'saint-joseph',
#  'ranong',
#  'wadi musa',
#  'udachnyy',
#  'port blair',
#  'prince rupert',
#  'bow island',
#  'buenos aires',
#  'broome',
#  'maple creek',
#  'hualmay',
#  'gillette',
#  'alwar',
#  'moshupa',
#  'agudos',
#  'belmonte',
#  'cody',
#  'avera',
#  'dalvik',
#  'la trinite',
#  'zarcero',
#  'bondoukou',
#  'araguacu',
#  'galle',
#  'praia da vitoria',
#  'celestun',
#  'mandera',
#  'petropavlovsk-kamchatskiy',
#  'cheuskiny',
#  'taburi',
#  'northam',
#  'chapada dos guimaraes',
#  'la rioja',
#  'bagotville',
#  'kameshkovo',
#  'verkhnyaya sinyachikha',
#  'naushahro firoz',
#  'quang ngai',
#  'kudahuvadhoo',
#  'college',
#  'margherita',
#  'kidal',
#  'acari',
#  'ortakoy',
#  'muros',
#  'abha',
#  'lawang',
#  'waingapu',
#  'lompoc',
#  'gorontalo',
#  'merauke',
#  'san nicolas',
#  'karangasem',
#  'chibombo',
#  'libiaz',
#  'florianopolis',
#  'antalaha',
#  'oranjestad',
#  'gizo',
#  'alenquer',
#  'gambela',
#  'edd',
#  'ciudad bolivar',
#  'acapulco',
#  'marquette',
#  'torrijos',
#  'rio gallegos',
#  'ponta delgada',
#  'pangai',
#  'mackay',
#  'santa cruz',
#  'ormond beach',
#  'sibolga',
#  'nelson bay',
#  'beruwala',
#  'ulladulla',
#  'vostok']

# %%
# Make a df to add data from API and drop any duplicates
cities_df = pd.DataFrame({'City': cities})
cities_df.drop_duplicates(subset='City')
cities_df
# Out:
#                City
# 0           ushuaia
# 1       tuktoyaktuk
# 2          kirakira
# 3           caceres
# 4         hithadhoo
# 5        north bend
# 6        luganville
# 7              nome
# 8             bluff
# 9           aklavik
# 10           atuona
# 11     norman wells
# 12         khatanga
# 13         cidreira
# 14          mataura
# 15           faanui
# 16            kapaa
# 17             miri
# 18     port-cartier
# 19        geraldton
# 20   severo-kurilsk
# 21         katsuura
# 22    lac du bonnet
# 23            nizwa
# 24          eskasem
# 25           albany
# 26       hutchinson
# 27         hare bay
# 28        norrtalje
# 29           samana
# ..              ...
# 557        waingapu
# 558          lompoc
# 559       gorontalo
# 560         merauke
# 561     san nicolas
# 562      karangasem
# 563        chibombo
# 564          libiaz
# 565   florianopolis
# 566        antalaha
# 567      oranjestad
# 568            gizo
# 569        alenquer
# 570         gambela
# 571             edd
# 572  ciudad bolivar
# 573        acapulco
# 574       marquette
# 575        torrijos
# 576    rio gallegos
# 577   ponta delgada
# 578          pangai
# 579          mackay
# 580      santa cruz
# 581    ormond beach
# 582         sibolga
# 583      nelson bay
# 584        beruwala
# 585       ulladulla
# 586          vostok
#
# [587 rows x 1 columns]

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key



column_names = ["City", "Country", "Date", "Temperature (F)",
                "Latitude","Longitude","Humidity (%)",
                "Cloudiness (%)", "Wind Speed (mph)"]

city_weather = pd.DataFrame(columns=column_names)

# Loop through cities using a count and add data to df 

count_row = 1
count_set = 1

print("Let The Data Retrieval Begin!")

for index, city in enumerate(cities):    
    if (index % 50 == 0 and index >= 50):
        count_set += 1
        count_row = 0
        
        
    #urllib.request.pathname2url(path)Convert the pathname path from the local syntax for a path to the form used in the path component of a URL. 
    city_url = url + "&q=" + urllib.request.pathname2url(city)
    
    print("Processing: Record %s of Set %s | %s" % (count_row, count_set, city))
    print(city_url)
    
    count_row += 1
    
    try:
        city_response = requests.get(city_url).json() 
    
        city_weather.set_value(index, 'City', city_response["name"])
        city_weather.set_value(index, 'Country', city_response["sys"]["country"])
        city_weather.set_value(index, 'Date', city_response["dt"])
        city_weather.set_value(index, 'Temperature (F)', city_response["main"]["temp"])
        city_weather.set_value(index, 'Humidity (%)', city_response["main"]["humidity"])
        city_weather.set_value(index, 'Cloudiness (%)', city_response["clouds"]["all"])
        city_weather.set_value(index, 'Wind Speed (mph)', city_response["wind"]["speed"])
        city_weather.set_value(index, 'Latitude', city_response["coord"]["lat"])
        city_weather.set_value(index, 'Longitude', city_response["coord"]["lon"])
        
    except:
        print("Must Be a Black Hole... City not found.")
        pass
    
print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# Let The Data Retrieval Begin!
# Processing: Record 1 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ushuaia
# Processing: Record 2 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tuktoyaktuk
# Processing: Record 3 of Set 1 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kirakira
# Processing: Record 4 of Set 1 | caceres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=caceres
# /Users/Ali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:39: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Ali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:40: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Ali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:41: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Ali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:42: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Ali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:43: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Ali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:44: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Ali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:45: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Ali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:46: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/Ali/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:47: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing: Record 5 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hithadhoo
# Processing: Record 6 of Set 1 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=north%20bend
# Processing: Record 7 of Set 1 | luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=luganville
# Processing: Record 8 of Set 1 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=nome
# Processing: Record 9 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bluff
# Processing: Record 10 of Set 1 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=aklavik
# Processing: Record 11 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=atuona
# Processing: Record 12 of Set 1 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=norman%20wells
# Processing: Record 13 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=khatanga
# Processing: Record 14 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=cidreira
# Processing: Record 15 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=mataura
# Processing: Record 16 of Set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=faanui
# Processing: Record 17 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kapaa
# Processing: Record 18 of Set 1 | miri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=miri
# Processing: Record 19 of Set 1 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=port-cartier
# Processing: Record 20 of Set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=geraldton
# Processing: Record 21 of Set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=severo-kurilsk
# Processing: Record 22 of Set 1 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=katsuura
# Processing: Record 23 of Set 1 | lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=lac%20du%20bonnet
# Processing: Record 24 of Set 1 | nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=nizwa
# Processing: Record 25 of Set 1 | eskasem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=eskasem
# Must Be a Black Hole... City not found.
# Processing: Record 26 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=albany
# Processing: Record 27 of Set 1 | hutchinson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hutchinson
# Processing: Record 28 of Set 1 | hare bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hare%20bay
# Processing: Record 29 of Set 1 | norrtalje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=norrtalje
# Processing: Record 30 of Set 1 | samana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=samana
# Processing: Record 31 of Set 1 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ilulissat
# Processing: Record 32 of Set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=torbay
# Processing: Record 33 of Set 1 | burica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=burica
# Must Be a Black Hole... City not found.
# Processing: Record 34 of Set 1 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=anadyr
# Processing: Record 35 of Set 1 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=itoman
# Processing: Record 36 of Set 1 | arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=arman
# Processing: Record 37 of Set 1 | luena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=luena
# Processing: Record 38 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=port%20alfred
# Processing: Record 39 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=cape%20town
# Processing: Record 40 of Set 1 | kushmurun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kushmurun
# Must Be a Black Hole... City not found.
# Processing: Record 41 of Set 1 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=husavik
# Processing: Record 42 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=busselton
# Processing: Record 43 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hilo
# Processing: Record 44 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=castro
# Processing: Record 45 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=saskylakh
# Processing: Record 46 of Set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=luderitz
# Processing: Record 47 of Set 1 | rognan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=rognan
# Processing: Record 48 of Set 1 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=codrington
# Processing: Record 49 of Set 1 | tahoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tahoua
# Processing: Record 50 of Set 1 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=sabang
# Processing: Record 0 of Set 2 | bamako
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bamako
# Processing: Record 1 of Set 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=upernavik
# Processing: Record 2 of Set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=arraial%20do%20cabo
# Processing: Record 3 of Set 2 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=sitka
# Processing: Record 4 of Set 2 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ahuimanu
# Processing: Record 5 of Set 2 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=longyearbyen
# Processing: Record 6 of Set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=nizhneyansk
# Must Be a Black Hole... City not found.
# Processing: Record 7 of Set 2 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=olafsvik
# Must Be a Black Hole... City not found.
# Processing: Record 8 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=mar%20del%20plata
# Processing: Record 9 of Set 2 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=amderma
# Must Be a Black Hole... City not found.
# Processing: Record 10 of Set 2 | puerto baquerizo moreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=puerto%20baquerizo%20moreno
# Processing: Record 11 of Set 2 | lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=lolua
# Must Be a Black Hole... City not found.
# Processing: Record 12 of Set 2 | lisakovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=lisakovsk
# Processing: Record 13 of Set 2 | fuente de oro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=fuente%20de%20oro
# Processing: Record 14 of Set 2 | tasbuget
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tasbuget
# Must Be a Black Hole... City not found.
# Processing: Record 15 of Set 2 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=dikson
# Processing: Record 16 of Set 2 | russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=russell
# Processing: Record 17 of Set 2 | mokrous
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=mokrous
# Processing: Record 18 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=qaanaaq
# Processing: Record 19 of Set 2 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=jumla
# Processing: Record 20 of Set 2 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=nikolskoye
# Processing: Record 21 of Set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=mahebourg
# Processing: Record 22 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=jamestown
# Processing: Record 23 of Set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=pevek
# Processing: Record 24 of Set 2 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=chokurdakh
# Processing: Record 25 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=saint-philippe
# Processing: Record 26 of Set 2 | kem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kem
# Processing: Record 27 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=punta%20arenas
# Processing: Record 28 of Set 2 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=caravelas
# Processing: Record 29 of Set 2 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hovd
# Processing: Record 30 of Set 2 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hasaki
# Processing: Record 31 of Set 2 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=rikitea
# Processing: Record 32 of Set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=taolanaro
# Must Be a Black Hole... City not found.
# Processing: Record 33 of Set 2 | eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=eyl
# Processing: Record 34 of Set 2 | bontang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bontang
# Processing: Record 35 of Set 2 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ostrovnoy
# Processing: Record 36 of Set 2 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=vanavara
# Processing: Record 37 of Set 2 | kanniyakumari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kanniyakumari
# Processing: Record 38 of Set 2 | novaya zaimka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=novaya%20zaimka
# Processing: Record 39 of Set 2 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hamilton
# Processing: Record 40 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hermanus
# Processing: Record 41 of Set 2 | dekoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=dekoa
# Must Be a Black Hole... City not found.
# Processing: Record 42 of Set 2 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=portland
# Processing: Record 43 of Set 2 | samalaeulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=samalaeulu
# Must Be a Black Hole... City not found.
# Processing: Record 44 of Set 2 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tiksi
# Processing: Record 45 of Set 2 | sadon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=sadon
# Processing: Record 46 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=east%20london
# Processing: Record 47 of Set 2 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=belushya%20guba
# Must Be a Black Hole... City not found.
# Processing: Record 48 of Set 2 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=pisco
# Processing: Record 49 of Set 2 | khonuu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=khonuu
# Must Be a Black Hole... City not found.
# Processing: Record 0 of Set 3 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=vaini
# Processing: Record 1 of Set 3 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=qasigiannguit
# Processing: Record 2 of Set 3 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=leningradskiy
# Processing: Record 3 of Set 3 | chimbote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=chimbote
# Processing: Record 4 of Set 3 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=barentsburg
# Must Be a Black Hole... City not found.
# Processing: Record 5 of Set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kodiak
# Processing: Record 6 of Set 3 | stromness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=stromness
# Processing: Record 7 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=port%20elizabeth
# Processing: Record 8 of Set 3 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=san%20patricio
# Processing: Record 9 of Set 3 | guilin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=guilin
# Processing: Record 10 of Set 3 | godo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=godo
# Processing: Record 11 of Set 3 | smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=smithers
# Processing: Record 12 of Set 3 | mugango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=mugango
# Processing: Record 13 of Set 3 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=lorengau
# Processing: Record 14 of Set 3 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=yellowknife
# Processing: Record 15 of Set 3 | elat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=elat
# Processing: Record 16 of Set 3 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=grand%20river%20south%20east
# Must Be a Black Hole... City not found.
# Processing: Record 17 of Set 3 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=avarua
# Processing: Record 18 of Set 3 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=harper
# Processing: Record 19 of Set 3 | calafell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=calafell
# Processing: Record 20 of Set 3 | katav-ivanovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=katav-ivanovsk
# Processing: Record 21 of Set 3 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=te%20anau
# Processing: Record 22 of Set 3 | malmo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=malmo
# Processing: Record 23 of Set 3 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=maniitsoq
# Processing: Record 24 of Set 3 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=sao%20joao%20da%20barra
# Processing: Record 25 of Set 3 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hobart
# Processing: Record 26 of Set 3 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=samusu
# Must Be a Black Hole... City not found.
# Processing: Record 27 of Set 3 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=palmer
# Processing: Record 28 of Set 3 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=zhangjiakou
# Processing: Record 29 of Set 3 | peleduy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=peleduy
# Processing: Record 30 of Set 3 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kavieng
# Processing: Record 31 of Set 3 | ulundi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ulundi
# Processing: Record 32 of Set 3 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=taoudenni
# Processing: Record 33 of Set 3 | trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=trinidad
# Processing: Record 34 of Set 3 | acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=acajutla
# Processing: Record 35 of Set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=butaritari
# Processing: Record 36 of Set 3 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=beringovskiy
# Processing: Record 37 of Set 3 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=esperance
# Processing: Record 38 of Set 3 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hobyo
# Processing: Record 39 of Set 3 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=xining
# Processing: Record 40 of Set 3 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=thompson
# Processing: Record 41 of Set 3 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=namibe
# Processing: Record 42 of Set 3 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=sisimiut
# Processing: Record 43 of Set 3 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=barrow
# Processing: Record 44 of Set 3 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=flinders
# Processing: Record 45 of Set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=new%20norfolk
# Processing: Record 46 of Set 3 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=adrar
# Processing: Record 47 of Set 3 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=coihaique
# Processing: Record 48 of Set 3 | sao lourenco do sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=sao%20lourenco%20do%20sul
# Processing: Record 49 of Set 3 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=airai
# Processing: Record 0 of Set 4 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=batemans%20bay
# Processing: Record 1 of Set 4 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=umzimvubu
# Must Be a Black Hole... City not found.
# Processing: Record 2 of Set 4 | abu kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=abu%20kamal
# Processing: Record 3 of Set 4 | karaul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=karaul
# Must Be a Black Hole... City not found.
# Processing: Record 4 of Set 4 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=grand%20gaube
# Processing: Record 5 of Set 4 | pafos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=pafos
# Must Be a Black Hole... City not found.
# Processing: Record 6 of Set 4 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=souillac
# Processing: Record 7 of Set 4 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=sola
# Processing: Record 8 of Set 4 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=saldanha
# Processing: Record 9 of Set 4 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bilma
# Processing: Record 10 of Set 4 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=salalah
# Processing: Record 11 of Set 4 | lieksa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=lieksa
# Processing: Record 12 of Set 4 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bethel
# Processing: Record 13 of Set 4 | darnah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=darnah
# Processing: Record 14 of Set 4 | pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=pochutla
# Processing: Record 15 of Set 4 | elk point
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=elk%20point
# Processing: Record 16 of Set 4 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=nanortalik
# Processing: Record 17 of Set 4 | piranshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=piranshahr
# Processing: Record 18 of Set 4 | ha tinh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ha%20tinh
# Processing: Record 19 of Set 4 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=saleaula
# Must Be a Black Hole... City not found.
# Processing: Record 20 of Set 4 | bell ville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bell%20ville
# Processing: Record 21 of Set 4 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=yarmouth
# Processing: Record 22 of Set 4 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=illoqqortoormiut
# Must Be a Black Hole... City not found.
# Processing: Record 23 of Set 4 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=berlevag
# Processing: Record 24 of Set 4 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=lebu
# Processing: Record 25 of Set 4 | horqueta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=horqueta
# Processing: Record 26 of Set 4 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=puerto%20ayora
# Processing: Record 27 of Set 4 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=constitucion
# Processing: Record 28 of Set 4 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tura
# Processing: Record 29 of Set 4 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=marcona
# Must Be a Black Hole... City not found.
# Processing: Record 30 of Set 4 | along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=along
# Processing: Record 31 of Set 4 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kruisfontein
# Processing: Record 32 of Set 4 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ugoofaaru
# Processing: Record 33 of Set 4 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=the%20valley
# Processing: Record 34 of Set 4 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=huarmey
# Processing: Record 35 of Set 4 | perth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=perth
# Processing: Record 36 of Set 4 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=carnarvon
# Processing: Record 37 of Set 4 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tuatapere
# Processing: Record 38 of Set 4 | tutoia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tutoia
# Processing: Record 39 of Set 4 | ariquemes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ariquemes
# Processing: Record 40 of Set 4 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bengkulu
# Must Be a Black Hole... City not found.
# Processing: Record 41 of Set 4 | benghazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=benghazi
# Processing: Record 42 of Set 4 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=victoria
# Processing: Record 43 of Set 4 | yatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=yatou
# Processing: Record 44 of Set 4 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=san%20quintin
# Processing: Record 45 of Set 4 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=qaqortoq
# Processing: Record 46 of Set 4 | kedrovoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kedrovoye
# Processing: Record 47 of Set 4 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=lasa
# Processing: Record 48 of Set 4 | marshall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=marshall
# Processing: Record 49 of Set 4 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=cherskiy
# Processing: Record 0 of Set 5 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=san%20cristobal
# Processing: Record 1 of Set 5 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=narsaq
# Processing: Record 2 of Set 5 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=fortuna
# Processing: Record 3 of Set 5 | satitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=satitoa
# Must Be a Black Hole... City not found.
# Processing: Record 4 of Set 5 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=la%20ronge
# Processing: Record 5 of Set 5 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=port%20hardy
# Processing: Record 6 of Set 5 | katangli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=katangli
# Processing: Record 7 of Set 5 | akoupe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=akoupe
# Processing: Record 8 of Set 5 | manadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=manadhoo
# Processing: Record 9 of Set 5 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=sao%20filipe
# Processing: Record 10 of Set 5 | volot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=volot
# Processing: Record 11 of Set 5 | am timan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=am%20timan
# Processing: Record 12 of Set 5 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=cockburn%20town
# Processing: Record 13 of Set 5 | sedona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=sedona
# Processing: Record 14 of Set 5 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kahului
# Processing: Record 15 of Set 5 | stokmarknes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=stokmarknes
# Processing: Record 16 of Set 5 | alghero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=alghero
# Processing: Record 17 of Set 5 | zvishavane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=zvishavane
# Processing: Record 18 of Set 5 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=shimoda
# Processing: Record 19 of Set 5 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=iqaluit
# Processing: Record 20 of Set 5 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=shingu
# Processing: Record 21 of Set 5 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=abu%20samrah
# Processing: Record 22 of Set 5 | basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=basco
# Processing: Record 23 of Set 5 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tasiilaq
# Processing: Record 24 of Set 5 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=leh
# Processing: Record 25 of Set 5 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=waipawa
# Processing: Record 26 of Set 5 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=inhambane
# Processing: Record 27 of Set 5 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ribeira%20grande
# Processing: Record 28 of Set 5 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=byron%20bay
# Processing: Record 29 of Set 5 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=sechura
# Processing: Record 30 of Set 5 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=klaksvik
# Processing: Record 31 of Set 5 | dvubratskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=dvubratskiy
# Processing: Record 32 of Set 5 | mapiripan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=mapiripan
# Processing: Record 33 of Set 5 | puerto colombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=puerto%20colombia
# Processing: Record 34 of Set 5 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bathsheba
# Processing: Record 35 of Set 5 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=umm%20lajj
# Processing: Record 36 of Set 5 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tumannyy
# Must Be a Black Hole... City not found.
# Processing: Record 37 of Set 5 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=vaitupu
# Must Be a Black Hole... City not found.
# Processing: Record 38 of Set 5 | ojinaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ojinaga
# Processing: Record 39 of Set 5 | raga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=raga
# Must Be a Black Hole... City not found.
# Processing: Record 40 of Set 5 | scottsbluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=scottsbluff
# Processing: Record 41 of Set 5 | grootfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=grootfontein
# Processing: Record 42 of Set 5 | najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=najran
# Processing: Record 43 of Set 5 | mascote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=mascote
# Processing: Record 44 of Set 5 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=provideniya
# Processing: Record 45 of Set 5 | le port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=le%20port
# Processing: Record 46 of Set 5 | skelleftea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=skelleftea
# Processing: Record 47 of Set 5 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=saint-francois
# Processing: Record 48 of Set 5 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=whitehorse
# Processing: Record 49 of Set 5 | raxaul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=raxaul
# Processing: Record 0 of Set 6 | khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=khani
# Processing: Record 1 of Set 6 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=cabo%20san%20lucas
# Processing: Record 2 of Set 6 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kaitangata
# Processing: Record 3 of Set 6 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=attawapiskat
# Must Be a Black Hole... City not found.
# Processing: Record 4 of Set 6 | kimberley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kimberley
# Processing: Record 5 of Set 6 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=lagoa
# Processing: Record 6 of Set 6 | la asuncion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=la%20asuncion
# Processing: Record 7 of Set 6 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=san%20policarpo
# Processing: Record 8 of Set 6 | kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kupang
# Processing: Record 9 of Set 6 | singapore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=singapore
# Processing: Record 10 of Set 6 | grand baie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=grand%20baie
# Processing: Record 11 of Set 6 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=fukue
# Processing: Record 12 of Set 6 | bosaso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bosaso
# Processing: Record 13 of Set 6 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tilichiki
# Processing: Record 14 of Set 6 | douentza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=douentza
# Processing: Record 15 of Set 6 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bredasdorp
# Processing: Record 16 of Set 6 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ponta%20do%20sol
# Processing: Record 17 of Set 6 | tsiroanomandidy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tsiroanomandidy
# Processing: Record 18 of Set 6 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=vardo
# Processing: Record 19 of Set 6 | vitimskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=vitimskiy
# Must Be a Black Hole... City not found.
# Processing: Record 20 of Set 6 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=okhotsk
# Processing: Record 21 of Set 6 | japura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=japura
# Processing: Record 22 of Set 6 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tsihombe
# Must Be a Black Hole... City not found.
# Processing: Record 23 of Set 6 | gold coast
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=gold%20coast
# Processing: Record 24 of Set 6 | casper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=casper
# Processing: Record 25 of Set 6 | makasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=makasar
# Processing: Record 26 of Set 6 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=champerico
# Processing: Record 27 of Set 6 | zabol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=zabol
# Processing: Record 28 of Set 6 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=touros
# Processing: Record 29 of Set 6 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=richards%20bay
# Processing: Record 30 of Set 6 | sulphur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=sulphur
# Processing: Record 31 of Set 6 | talant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=talant
# Processing: Record 32 of Set 6 | presidente venceslau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=presidente%20venceslau
# Processing: Record 33 of Set 6 | libreville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=libreville
# Processing: Record 34 of Set 6 | ipil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ipil
# Processing: Record 35 of Set 6 | san clemente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=san%20clemente
# Processing: Record 36 of Set 6 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hofn
# Processing: Record 37 of Set 6 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bandarbeyla
# Processing: Record 38 of Set 6 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=louisbourg
# Must Be a Black Hole... City not found.
# Processing: Record 39 of Set 6 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ballina
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tocopilla
# Processing: Record 38 of Set 10 | maykain
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=maykain
# Must Be a Black Hole... City not found.
# Processing: Record 39 of Set 10 | nevelsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=nevelsk
# Processing: Record 40 of Set 10 | pemangkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=pemangkat
# Must Be a Black Hole... City not found.
# Processing: Record 41 of Set 10 | wenatchee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=wenatchee
# Processing: Record 42 of Set 10 | chornoliztsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=chornoliztsi
# Processing: Record 43 of Set 10 | mwingi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=mwingi
# Processing: Record 44 of Set 10 | langarud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=langarud
# Processing: Record 45 of Set 10 | cascais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=cascais
# Processing: Record 46 of Set 10 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=marsh%20harbour
# Processing: Record 47 of Set 10 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=quatre%20cocos
# Processing: Record 48 of Set 10 | tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tiznit
# Processing: Record 49 of Set 10 | aasiaat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=aasiaat
# Processing: Record 0 of Set 11 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hambantota
# Processing: Record 1 of Set 11 | puerto carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=puerto%20carreno
# Processing: Record 2 of Set 11 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=severo-yeniseyskiy
# Processing: Record 3 of Set 11 | nykoping
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=nykoping
# Processing: Record 4 of Set 11 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=nantucket
# Processing: Record 5 of Set 11 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=talnakh
# Processing: Record 6 of Set 11 | kurchum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kurchum
# Processing: Record 7 of Set 11 | tidore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=tidore
# Must Be a Black Hole... City not found.
# Processing: Record 8 of Set 11 | stepnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=stepnogorsk
# Processing: Record 9 of Set 11 | bagn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bagn
# Processing: Record 10 of Set 11 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=saint-joseph
# Processing: Record 11 of Set 11 | ranong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ranong
# Processing: Record 12 of Set 11 | wadi musa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=wadi%20musa
# Processing: Record 13 of Set 11 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=udachnyy
# Processing: Record 14 of Set 11 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=port%20blair
# Processing: Record 15 of Set 11 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=prince%20rupert
# Processing: Record 16 of Set 11 | bow island
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bow%20island
# Processing: Record 17 of Set 11 | buenos aires
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=buenos%20aires
# Processing: Record 18 of Set 11 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=broome
# Processing: Record 19 of Set 11 | maple creek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=maple%20creek
# Processing: Record 20 of Set 11 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=hualmay
# Processing: Record 21 of Set 11 | gillette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=gillette
# Processing: Record 22 of Set 11 | alwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=alwar
# Processing: Record 23 of Set 11 | moshupa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=moshupa
# Processing: Record 24 of Set 11 | agudos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=agudos
# Processing: Record 25 of Set 11 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=belmonte
# Processing: Record 26 of Set 11 | cody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=cody
# Processing: Record 27 of Set 11 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=avera
# Processing: Record 28 of Set 11 | dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=dalvik
# Processing: Record 29 of Set 11 | la trinite
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=la%20trinite
# Processing: Record 30 of Set 11 | zarcero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=zarcero
# Processing: Record 31 of Set 11 | bondoukou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bondoukou
# Processing: Record 32 of Set 11 | araguacu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=araguacu
# Must Be a Black Hole... City not found.
# Processing: Record 33 of Set 11 | galle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=galle
# Processing: Record 34 of Set 11 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=praia%20da%20vitoria
# Processing: Record 35 of Set 11 | celestun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=celestun
# Processing: Record 36 of Set 11 | mandera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=mandera
# Processing: Record 37 of Set 11 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=petropavlovsk-kamchatskiy
# Processing: Record 38 of Set 11 | cheuskiny
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=cheuskiny
# Must Be a Black Hole... City not found.
# Processing: Record 39 of Set 11 | taburi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=taburi
# Must Be a Black Hole... City not found.
# Processing: Record 40 of Set 11 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=northam
# Processing: Record 41 of Set 11 | chapada dos guimaraes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=chapada%20dos%20guimaraes
# Processing: Record 42 of Set 11 | la rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=la%20rioja
# Processing: Record 43 of Set 11 | bagotville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=bagotville
# Processing: Record 44 of Set 11 | kameshkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kameshkovo
# Processing: Record 45 of Set 11 | verkhnyaya sinyachikha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=verkhnyaya%20sinyachikha
# Processing: Record 46 of Set 11 | naushahro firoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=naushahro%20firoz
# Processing: Record 47 of Set 11 | quang ngai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=quang%20ngai
# Processing: Record 48 of Set 11 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kudahuvadhoo
# Processing: Record 49 of Set 11 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=college
# Processing: Record 0 of Set 12 | margherita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=margherita
# Processing: Record 1 of Set 12 | kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=kidal
# Processing: Record 2 of Set 12 | acari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=acari
# Processing: Record 3 of Set 12 | ortakoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ortakoy
# Processing: Record 4 of Set 12 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=muros
# Processing: Record 5 of Set 12 | abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=abha
# Processing: Record 6 of Set 12 | lawang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=lawang
# Processing: Record 7 of Set 12 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=waingapu
# Processing: Record 8 of Set 12 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=lompoc
# Processing: Record 9 of Set 12 | gorontalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=gorontalo
# Processing: Record 10 of Set 12 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=merauke
# Processing: Record 11 of Set 12 | san nicolas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=san%20nicolas
# Processing: Record 12 of Set 12 | karangasem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=karangasem
# Processing: Record 13 of Set 12 | chibombo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=chibombo
# Processing: Record 14 of Set 12 | libiaz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=libiaz
# Processing: Record 15 of Set 12 | florianopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=florianopolis
# Processing: Record 16 of Set 12 | antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=antalaha
# Processing: Record 17 of Set 12 | oranjestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=oranjestad
# Processing: Record 18 of Set 12 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=gizo
# Processing: Record 19 of Set 12 | alenquer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=alenquer
# Processing: Record 20 of Set 12 | gambela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=gambela
# Processing: Record 21 of Set 12 | edd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=edd
# Processing: Record 22 of Set 12 | ciudad bolivar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ciudad%20bolivar
# Processing: Record 23 of Set 12 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=acapulco
# Processing: Record 24 of Set 12 | marquette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=marquette
# Processing: Record 25 of Set 12 | torrijos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=torrijos
# Processing: Record 26 of Set 12 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=rio%20gallegos
# Processing: Record 27 of Set 12 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ponta%20delgada
# Processing: Record 28 of Set 12 | pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=pangai
# Processing: Record 29 of Set 12 | mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=mackay
# Processing: Record 30 of Set 12 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=santa%20cruz
# Processing: Record 31 of Set 12 | ormond beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ormond%20beach
# Processing: Record 32 of Set 12 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=sibolga
# Processing: Record 33 of Set 12 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=nelson%20bay
# Processing: Record 34 of Set 12 | beruwala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=beruwala
# Processing: Record 35 of Set 12 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=ulladulla
# Processing: Record 36 of Set 12 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd8b9a7f2e3bdad98653d33880777d7f&q=vostok
# -----------------------------
# Data Retrieval Complete

# %%
city_weather.count()
# Out:
# City                533
# Country             533
# Temperature (F)     533
# Latitude            533
# Longitude           533
# Humidity (%)        533
# Cloudiness (%)      533
# Wind Speed (mph)    533
# Date                533
# dtype: int64

# %%
city_weather.head(5)
# Out:
#           City Country Temperature (F) Latitude Longitude Humidity (%)  \
# 0      Ushuaia      AR           36.39   -54.81    -68.31          100
# 1  Tuktoyaktuk      CA            39.2    69.44   -133.03           80
# 2     Kirakira      SB           80.59   -10.46    161.92          100
# 3      Caceres      CO           78.43     5.53    -74.53           58
# 4    Hithadhoo      MV           83.56     -0.6     73.08          100
#
#   Cloudiness (%) Wind Speed (mph)          Date
# 0              0            13.87  1.533996e+09
# 1             90            14.99  1.533997e+09
# 2             92            17.25  1.534000e+09
# 3              0             1.59  1.534000e+09
# 4            100             9.42  1.534000e+09

# %%
city_weather.to_csv(output_data_file, index_label = "cities.csv")

# %%
from matplotlib import cm
from colorspacious import cspace_converter
from collections import OrderedDict

cmaps = OrderedDict()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-260-5d44f7dc3444> in <module>()
#       1 from matplotlib import cm
# ----> 2 from colorspacious import cspace_converter
#       3 from collections import OrderedDict
#       4
#       5 cmaps = OrderedDict()
#
# ModuleNotFoundError: No module named 'colorspacious'

# %%
lat= city_weather['Latitude']
temp = city_weather['Temperature (F)']
humid = city_weather['Humidity (%)']
clouds = city_weather['Cloudiness (%)']
wind = city_weather['Wind Speed (mph)']

# %%
plt.scatter(lat,temp, edgecolor='black', linewidths=1, cmap='cool', marker="o", alpha=0.8)

# Incorporate the other graph properties

plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
plt.scatter(lat,humid, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label=cities)

plt.title("City Latitude vs. Himidity (%s)" % time.strftime("%x"))
plt.ylabel("Himidity (%s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
plt.scatter(lat,clouds,edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")


plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig3.png")
